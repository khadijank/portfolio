# %%
pip install pyproj

# %%
pip install geopandas

# %%
pip install osmnx

# %%
#pip uninstall numpy

# %%
#pip install numpy==1.23.1

# %%
pip install folium matplotlib mapclassify

# %% [markdown]
# # Spatial Mapping of Automated Ticket Devices in Edmonton

# %% [markdown]
# Khadija Naeem
#
# 2023-04-21

# %%
## Import Packages
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
import contextlib
from packaging.version import Version
import importlib
import os
import warnings

import numpy as np
import pandas as pd
import pyproj
import shapely
import shapely.geos

# %%
#Upload dataframe to be input into geopandas
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93308bfd-9ab7-481d-8f7a-fb2cb51fc7a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93308bfd-9ab7-481d-8f7a-fb2cb51fc7a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Photoradar Tickets_Jan 2022.csv']))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Location                  255 non-null    object
#  1   Enforced Speed Limit      255 non-null    int64
#  2   Month End Date            255 non-null    object
#  3   Deployment Hours          255 non-null    float64
#  4   1-5 Over Speed Limit      255 non-null    int64
#  5   6-10 Over Speed Limit     255 non-null    int64
#  6   11-15 Over Speed Limit    255 non-null    int64
#  7   16-20 Over Speed Limit    255 non-null    int64
#  8   21-50 Over Speed Limit    255 non-null    int64
#  9   51+ Over Speed Limit      255 non-null    int64
#  10  Total Speeding Tickets    255 non-null    int64
#  11  Latitude                  255 non-null    float64
#  12  Longitude                 255 non-null    float64
#  13  New Georeferenced Column  255 non-null    object
# ...

# %% [markdown]
# Mapping of Automated Mobile Tickets Issued by Device

# %%
import geopandas as gpd
tickets = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# %%
tickets.head()
# Out:
#                                   Location  Enforced Speed Limit  \
# 0                (53.4881471,-113.5449254)                    30
# 1   (53.54938884449274,-113.4424127188402)                    50
# 2   (53.6375625772882,-113.40232571310747)                   100
# 3  (53.54139789683596,-113.63190288107342)                    60
# 4  (53.51046927843755,-113.49767583406245)                    50
#
#   Month End Date  Deployment Hours  1-5 Over Speed Limit  \
# 0       Jan 2022            8.8000                     0
# 1       Jan 2022           23.6167                     0
# 2       Jan 2022           40.5833                     0
# 3       Jan 2022           74.8833                     0
# 4       Jan 2022           31.8333                     0
#
#    6-10 Over Speed Limit  11-15 Over Speed Limit  16-20 Over Speed Limit  \
# 0                      1                       0                       0
# 1                      2                       5                       0
# ...

# %%
#downloading edmonton street map from OpenStreetMap
import osmnx as ox
ed = ox.geocode_to_gdf({'city': 'Edmonton'})
ed
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-113.71384 53.56981, -113.71384 53.5...   53.716265   53.337256
#
#     bbox_east   bbox_west   place_id  osm_type   osm_id        lat  \
# 0 -113.271478 -113.713841  298643052  relation  2564500  53.546205
#
#           lon               display_name  class  type  importance
# 0 -113.491241  Edmonton, Alberta, Canada  place  city    0.740884

# %%
#downloading edmonton shapely image file
edmonton_poly = shapely.wkt.loads(
.6898802 53.592943, -113.6904595 53.5926957, -113.6909667 53.5924328, -113.692157 53.5921899, -113.6926107 53.5921368, -113.6944345 53.5921197, -113.6955075 53.59213, -113.6967875 53.5922522, -113.6976667 53.592437, -113.69824 53.5925244, -113.6989085 53.592547, -113.6994573 53.5924291, -113.6999333 53.5924196, -113.7001254 53.5923564, -113.7005033 53.5923592, -113.701063 53.5924354, -113.7015557 53.592585, -113.701976 53.5926236, -113.7021968 53.5925747, -113.7023261 53.5923985, -113.7025913 53.5922268, -113.7028759 53.5921565, -113.7035106 53.5921756, -113.7043588 53.5922992, -113.705266 53.5923273, -113.7064238 53.5922322, -113.7078519 53.5926136, -113.7108641 53.5926975, -113.7129072 53.592408, -113.7137416 53.5923707, -113.7137066 53.5841046, -113.7138411 53.5698121))"	
    )

# %%
from shapely.geometry import Point
# import osmnx as ox
# city = ox.graph_from_place('Edmonton, Alberta, Canada')

# plot edmonton city limits
from geopandas import GeoDataFrame as gdf
m = gpd.GeoDataFrame(geometry=[edmonton_poly], crs="epsg:4326").explore(name="Edmonton", height=1000, width=1000)
# plot the points, just for demo purposes plot outcomes as different colors
m = tickets.explore(m=m, marker_kwds=dict(radius=1, fill=True), scheme="User_Defined", classification_kwds=dict(bins=[0,10,20,30,40,50,70,100,130,200,400]), cmap='plasma', vmax=405, vmin=0, legend=True, column="Total Speeding Tickets", name="photoradar devices")
# add layer control so layers can be switched on / off
import folium
folium.LayerControl().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Photoradar Tickets Issued vs. Plow Requests

# %%
uploaded2 = files.upload()
df2 = pd.read_csv(io.BytesIO(uploaded2['Pothole Requests_Jan 2022.csv']))
df2.info()
# Out:
#      <input type="file" id="files-16117470-a19c-4e52-9864-b213111d0e23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16117470-a19c-4e52-9864-b213111d0e23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
potholes = gpd.GeoDataFrame(
    df2, geometry=gpd.points_from_xy(df2.Long, df2.Lat))

# %%
m = gpd.GeoDataFrame(geometry=[edmonton_poly], crs="epsg:4326").explore(name="Edmonton", height=1000, width=1000)
# plot the points, just for demo purposes plot outcomes as different colors
m = tickets.explore(m=m, marker_kwds=dict(radius=1, fill=True), scheme="User_Defined", classification_kwds=dict(bins=[0,10,20,30,40,50,70,100,130,200,400]), cmap='plasma', vmax=405, vmin=0, legend=True, column="Total Speeding Tickets", name="photoradar devices")
m = potholes.explore(m=m, column='Number of Requests', color='green', marker_type='marker', legend=False, marker_kwds=dict(radius=0.05, fill=True), name='requests')
# add layer control so layers can be switched on / off
import folium
folium.LayerControl().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Photoradar Tickets Issued vs. Planned Construction

# %%
uploaded3 = files.upload()
df3 = pd.read_csv(io.BytesIO(uploaded3['Planned Construction_2022.csv']))
df3.info()
# Out:
#      <input type="file" id="files-cc63ecc0-a5d2-4905-8c99-5ce403ec3a8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc63ecc0-a5d2-4905-8c99-5ce403ec3a8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
construction = gpd.GeoDataFrame(
    df3, geometry=gpd.points_from_xy(df3.Longitude, df3.Latitude))

# %%
m = gpd.GeoDataFrame(geometry=[edmonton_poly], crs="epsg:4326").explore(name="Edmonton", height=1000, width=1000)
# plot the points, just for demo purposes plot outcomes as different colors
m = tickets.explore(m=m, marker_kwds=dict(radius=1, fill=True), scheme="User_Defined", classification_kwds=dict(bins=[0,10,20,30,40,50,70,100,130,200,400]), cmap='plasma', vmax=405, vmin=0, legend=True, column="Total Speeding Tickets", name="photoradar devices")
m = construction.explore(m=m, column='Record', color='green', legend=False, marker_type='marker', marker_kwds=dict(radius=0.05, fill=True), name='requests')
# add layer control so layers can be switched on / off
import folium
folium.LayerControl().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Photoradar Tickets Issued vs. Plow Requests (Jan 2022)

# %%
uploaded4 = files.upload()
df4 = pd.read_csv(io.BytesIO(uploaded4['Plow Requests_Jan 2022.csv']))
df4.info()
# Out:
#      <input type="file" id="files-5342fd91-866a-443c-956a-3f9647d5203d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5342fd91-866a-443c-956a-3f9647d5203d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plow = gpd.GeoDataFrame(
    df4, geometry=gpd.points_from_xy(df4.Long, df4.Lat))

# %%
m = gpd.GeoDataFrame(geometry=[edmonton_poly], crs="epsg:4326").explore(name="Edmonton", height=1000, width=1000)
# plot the points, just for demo purposes plot outcomes as different colors
m = tickets.explore(m=m, marker_kwds=dict(radius=3, fill=True), scheme="User_Defined", classification_kwds=dict(bins=[0,10,20,30,40,50,70,100,130,200,400]), cmap='plasma', vmax=405, vmin=0, legend=True, column="Total Speeding Tickets", name="photoradar devices")
m = plow.explore(m=m, column='Request', color='green', marker_type='marker', legend=False, marker_kwds=dict(radius=0.001, fill=True), name='requests')
# add layer control so layers can be switched on / off
folium.LayerControl().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Photoradar Tickets vs Criminal Flight Offences (Sept 2022)

# %%
uploaded5 = files.upload()
df5 = pd.read_csv(io.BytesIO(uploaded5['Photoradar Tickets_Sept 2022.csv']))
df5.info()
# Out:
#      <input type="file" id="files-a715e976-103a-48ec-ac58-a57550d069ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a715e976-103a-48ec-ac58-a57550d069ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded6 = files.upload()
df6 = pd.read_csv(io.BytesIO(uploaded6['Criminal Flights_Sept 2022.csv']))
df6.info()
# Out:
#      <input type="file" id="files-8c284459-8399-4ca9-8ce9-9092bc4c2e45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c284459-8399-4ca9-8ce9-9092bc4c2e45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
tickets2 = gpd.GeoDataFrame(
    df5, geometry=gpd.points_from_xy(df5.Longitude, df5.Latitude))

# %%
offenses = gpd.GeoDataFrame(
    df6, geometry=gpd.points_from_xy(df6.X, df6.Y))

# %%
m = gpd.GeoDataFrame(geometry=[edmonton_poly], crs="epsg:4326").explore(name="Edmonton", height=1000, width=1000)
# plot the points, just for demo purposes plot outcomes as different colors
m = tickets2.explore(m=m, marker_kwds=dict(radius=3, fill=True), scheme="User_Defined", classification_kwds=dict(bins=[0,10,20,30,40,50,70,100,130,200,400,30000]), cmap='plasma', vmax=405, vmin=0, legend=True, column="Total Speeding Tickets", name="photoradar devices")
m = offenses.explore(m=m, column='OBJECTID', color='green', marker_type='marker', legend=False, marker_kwds=dict(radius=0.5, fill=True), name='OBJECTID')
# add layer control so layers can be switched on / off
folium.LayerControl().add_to(m)

# %%
m
